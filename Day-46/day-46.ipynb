# %% [markdown]
# ### Task 1
# - Run object detection on any image.

# %% [markdown]
# ### Task 2
# Write down:
# - Detected Objects
# - Confidence Scores

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")

# %%
results = model("test_2.jpeg", conf=0.5)
results[0].show()
# Out:
# image 1/1 d:\AI-ML-Internship\Day-46\test_2.jpeg: 640x512 2 persons, 3 cars, 1 truck, 112.8ms
# Speed: 6.2ms preprocess, 112.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)

# %%
for result in results: 
    print(result.names)
# Out:
# {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'micr
# ...

# %%
#detected objects and confidence scores
for result in results:
    for box in result.boxes:
        cls_id = int(box.cls[0])
        conf = float(box.conf[0])

        class_name = model.names[cls_id]
        print(f"{class_name} -> {conf*100:.2f}%")
# Out:
# car -> 91.97%
# car -> 88.49%
# person -> 67.78%
# person -> 60.61%
# car -> 60.26%
# truck -> 54.47%

# %% [markdown]
# ### Task 3
# Experiment with:
# - conf=0.3
# - conf=0.5
# - conf=0.8
# Observe differences.

# %%
# conf = 0.3
result_1 = model("test_2.jpeg",conf=0.3)
result_1[0].show()

#detected objects and confidence scores
for result in result_1:
    for box in result.boxes:
        cls_id = int(box.cls[0])
        conf = float(box.conf[0])

        class_name = model.names[cls_id]
        print(f"{class_name} -> {conf*100:.2f}%")
# Out:
# image 1/1 d:\AI-ML-Internship\Day-46\test_2.jpeg: 640x512 5 persons, 5 cars, 1 truck, 108.6ms
# Speed: 2.8ms preprocess, 108.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
# car -> 91.97%
# car -> 88.49%
# person -> 67.78%
# person -> 60.61%
# car -> 60.26%
# truck -> 54.47%
# person -> 42.80%
# car -> 42.71%
# person -> 41.10%
# car -> 36.71%
# person -> 31.47%

# %%
# conf = 0.5
result_2 = model("test_2.jpeg",conf=0.5)
result_2[0].show()

#detected objects and confidence scores
for result in result_2:
    for box in result.boxes:
        cls_id = int(box.cls[0])
        conf = float(box.conf[0])

        class_name = model.names[cls_id]
        print(f"{class_name} -> {conf*100:.2f}%")
# Out:
# image 1/1 d:\AI-ML-Internship\Day-46\test_2.jpeg: 640x512 2 persons, 3 cars, 1 truck, 90.0ms
# Speed: 3.4ms preprocess, 90.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
# car -> 91.97%
# car -> 88.49%
# person -> 67.78%
# person -> 60.61%
# car -> 60.26%
# truck -> 54.47%

# %%
# conf = 0.8
result_3 = model("test_2.jpeg",conf=0.8)
result_3[0].show()

#detected objects and confidence scores
for result in result_3:
    for box in result.boxes:
        cls_id = int(box.cls[0])
        conf = float(box.conf[0])

        class_name = model.names[cls_id]
        print(f"{class_name} -> {conf*100:.2f}%")
# Out:
# image 1/1 d:\AI-ML-Internship\Day-46\test_2.jpeg: 640x512 2 cars, 92.6ms
# Speed: 2.9ms preprocess, 92.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
# car -> 91.97%
# car -> 88.49%

# %% [markdown]
# ### Task 4
# Print result.boxes
# and analyze output.

# %% [markdown]
# ### Task 5
# Identify:
#  - Object Class
#  - Confidence
#  - Bounding Box
# for every detected object.

# %%
results = model("test_2.jpeg", conf=0.5)
results[0].show()
# Out:
# image 1/1 d:\AI-ML-Internship\Day-46\test_2.jpeg: 640x512 2 persons, 3 cars, 1 truck, 144.1ms
# Speed: 2.8ms preprocess, 144.1ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 512)

# %%
for result in results:
    print(result.boxes)
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2., 2., 0., 0., 2., 7.])
# conf: tensor([0.9197, 0.8849, 0.6778, 0.6061, 0.6026, 0.5447])
# data: tensor([[1.1471e+02, 6.7653e+02, 4.3590e+02, 8.9821e+02, 9.1972e-01, 2.0000e+00],
#         [0.0000e+00, 6.9121e+02, 1.3616e+02, 9.3283e+02, 8.8488e-01, 2.0000e+00],
#         [3.4297e+02, 6.2897e+02, 3.7975e+02, 6.9552e+02, 6.7779e-01, 0.0000e+00],
#         [4.2897e+02, 7.1132e+02, 5.0567e+02, 8.5024e+02, 6.0614e-01, 0.0000e+00],
#         [8.3200e+01, 6.0455e+02, 1.2187e+02, 6.3405e+02, 6.0260e-01, 2.0000e+00],
#         [1.2083e+02, 7.9534e+02, 9.6000e+02, 1.2459e+03, 5.4474e-01, 7.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1247, 960)
# shape: torch.Size([6, 6])
# xywh: tensor([[ 275.3075,  787.3715,  321.1890,  221.6869],
#         [  68.0801,  812.0193,  136.1602,  241.6277],
#         [ 361.3616,  662.2434,   36.7788,   66.5438],
#         [ 467.3166,  780.7806,   76.6996,  138.9246],
# ...

# %%
result = results[0]

for box in result.boxes:
    class_id = int(box.cls[0])
    confidence = float(box.conf[0])
    bbox = box.xyxy[0].tolist()

    print("Class:", model.names[class_id])
    print("Confidence:", confidence)
    print("Bounding Box:", bbox)
    print()
# Out:
# Class: car
# Confidence: 0.9197199940681458
# Bounding Box: [114.7130355834961, 676.528076171875, 435.90203857421875, 898.2149658203125]
#
# Class: car
# Confidence: 0.8848815560340881
# Bounding Box: [0.0, 691.2054443359375, 136.16024780273438, 932.8331298828125]
#
# Class: person
# Confidence: 0.6777948141098022
# Bounding Box: [342.97222900390625, 628.9714965820312, 379.7510070800781, 695.5153198242188]
#
# Class: person
# Confidence: 0.6061385869979858
# Bounding Box: [428.9668273925781, 711.318359375, 505.6663818359375, 850.2429809570312]
#
# Class: car
# Confidence: 0.6026009321212769
# Bounding Box: [83.19976043701172, 604.5455322265625, 121.8676986694336, 634.0510864257812]
#
# Class: truck
# Confidence: 0.5447437167167664
# Bounding Box: [120.82515716552734, 795.3419189453125, 960.0, 1245.8780517578125]
