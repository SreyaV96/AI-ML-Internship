# %% [markdown]
# ### Task 1
# Install Gensim:
# pip install gensim

# %% [markdown]
# ### Task 2
# Load the GloVe model.

# %%
import gensim.downloader as api
model = api.load("glove-wiki-gigaword-50")
# Out:
# [==================================================] 100.0% 66.0/66.0MB downloaded

# %% [markdown]
# ### Task 3
# Print the vector for:
#
# king

# %%
print(model["king"])
# Out:
# [ 0.50451   0.68607  -0.59517  -0.022801  0.60046  -0.13498  -0.08813
#   0.47377  -0.61798  -0.31012  -0.076666  1.493    -0.034189 -0.98173
#   0.68229   0.81722  -0.51874  -0.31503  -0.55809   0.66421   0.1961
#  -0.13495  -0.11476  -0.30344   0.41177  -2.223    -1.0756   -1.0783
#  -0.34354   0.33505   1.9927   -0.04234  -0.64319   0.71125   0.49159
#   0.16754   0.34344  -0.25663  -0.8523    0.1661    0.40102   1.1685
#  -1.0137   -0.21585  -0.15155   0.78321  -0.91241  -1.6106   -0.64426
#  -0.51042 ]

# %% [markdown]
# ### Task 4
# Find the top 5 similar words for:
#
# computer

# %%
model = api.load("glove-wiki-gigaword-50") 
similar_words = model.most_similar("computer", topn=5)

for word, score in similar_words:
    print(word, ":", score)
# Out:
# computers : 0.9165045022964478
# software : 0.8814992904663086
# technology : 0.852556049823761
# electronic : 0.812586784362793
# internet : 0.8060455322265625

# %%
model = api.load("fasttext-wiki-news-subwords-300")
similar_words = model.most_similar("computer", topn=5)

for word, score in similar_words:
    print(word, ":", score)
# Out:
# [==================================================] 100.0% 958.5/958.4MB downloaded
# computers : 0.8472651243209839
# non-computer : 0.8156518936157227
# mini-computer : 0.8099768757820129
# micro-computer : 0.7727647423744202
# super-computer : 0.762492299079895

# %% [markdown]
# ### Task 5
# Research one real-world application of FastText and explain why it is suitable.

# %% [markdown]
# #### Spam Email Detection
#
# FastText is widely used for spam email detection, where emails are automatically classified as spam or not spam (ham).
#
# Eg: Congratulashuns! Clik here to get your FREE mobyle phone!!
#
# Even though words are misspelled, FastText uses character n-grams to recognize that they are similar to:
#
# Congratulations, Click, Mobile
#
# So it still predicts: spam
#
# ##### Why FastText is suitable:
#
# - Uses character n-grams, allowing it to recognize words even if they are misspelled (e.g., fr33, winnner).
# - Handles Out-of-Vocabulary (OOV) words by generating vectors from subwords.
# - Provides fast training and prediction, making it suitable for processing millions of emails.
# - Achieves high accuracy in text classification tasks.

# %% [markdown]
# ###
