# %% [markdown]
# ### Task 1
# Convert the following sentence to lowercase: HELLO, I WANT TO BOOK A TICKET.

# %%
user_input = "HELLO, I WANT TO BOOK A TICKET"
user_input_lower = user_input.lower()
print(user_input_lower)
# Out:
# hello, i want to book a ticket

# %% [markdown]
# ### Task 2
# Tokenize the sentence:
# I love learning Artificial Intelligence.

# %%
sentence = "I love learning Artificial Intelligence."
tokens = sentence.split()
print(tokens)
# Out:
# ['I', 'love', 'learning', 'Artificial', 'Intelligence.']

# %% [markdown]
# ### Task 3
# Identify the intent and entities:
# Book a flight to Chennai on Friday

# %% [markdown]
# - intent : flight booking
# - entities : chennai, Friday

# %% [markdown]
# ### Task 4
# Write a Python program to tokenize a sentence using split()

# %%
text = input("Enter a sentence:").lower()
text_tokens = text.split()
print(text_tokens)
# Out:
# ['i', 'want', 'to', 'book', 'a', 'flight', 'to', 'bangalore', 'tomorrow']

# %% [markdown]
# ### Task 5
# Create a table showing the difference between Stemming and Lemmatization.

# %% [markdown]
# | Stemming                                            | Lemmatization                                   |
# | --------------------------------------------------- | ----------------------------------------------- |
# | Removes prefixes or suffixes to find the root word. | Converts words to their dictionary (base) form. |
# | Faster process.                                     | Slower but more accurate.                       |
# | May produce invalid words.                          | Produces meaningful words.                      |
# | Does not require a dictionary.                      | Requires a dictionary (lexicon).                |
# | Example: studies → studi                            | Example: studies → study                        |
